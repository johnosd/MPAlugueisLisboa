# %%
import requests
import pandas as pd

def fetch_weather_data(api_key, location, start_d, end_d, frequency):
    # URL da API
    url_page = f'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key={api_key}&q={location}&format=json&date={start_d}&enddate={end_d}&tp={str(frequency)}'
    
    # Fazendo a requisição para a API
    response = requests.get(url_page)
    
    # Verificando se a requisição foi bem-sucedida
    if response.status_code == 200:
        data = response.json()

        # Extraindo dados relevantes do JSON
        weather_data = data['data']['weather']
        
        # Lista para armazenar as informações a serem transformadas em DataFrame
        weather_list = []

        query = data['data']['request'][0]['query']
        
        for day in weather_data:
            date = day['date']
            max_temp = day['maxtempC']
            min_temp = day['mintempC']
            avg_temp = day['avgtempC']
            sun_hours = day['sunHour']
            uv_index = day['uvIndex']
            astronomy = day['astronomy'][0]
            sunrise = astronomy['sunrise']
            sunset = astronomy['sunset']
            moonrise = astronomy['moonrise']
            moonset = astronomy['moonset']
            
            # Extraindo dados horáros
            hourly_data = day['hourly']
            for hour in hourly_data:
                time = hour['time']
                temp = hour['tempC']
                humidity = hour['humidity']
                wind_speed = hour['windspeedKmph']
                weather_desc = hour['weatherDesc'][0]['value']
                precip_mm = hour['precipMM']
                
                # Adicionando os dados coletados à lista
                weather_list.append({
                    'location': location,
                    'query': query,
                    'date': date,
                    'time': time,
                    'temp_C': temp,
                    'humidity': humidity,
                    'wind_speed_Kmph': wind_speed,
                    'weather_desc': weather_desc,
                    'precip_mm': precip_mm,
                    'max_temp_C': max_temp,
                    'min_temp_C': min_temp,
                    'avg_temp_C': avg_temp,
                    'sun_hours': sun_hours,
                    'uv_index': uv_index,
                    'sunrise': sunrise,
                    'sunset': sunset,
                    'moonrise': moonrise,
                    'moonset': moonset
                })
        
        # Criando o DataFrame com os dados coletados
        df = pd.DataFrame(weather_list)
        return df
    else:
        print(f"Erro na requisição: {response.status_code}")
        return None

# %%
# Exemplo de uso
api_key = "a486a31885364323a5a211207250307"
location = "Sao Paulo, Brazil"
start_d = "2025-07-13"
end_d = "2025-07-14"
frequency = 1  # Intervalo de 3 horas

weather_df = fetch_weather_data(api_key, location, start_d, end_d, frequency)

# %%
# Exibindo o DataFrame
weather_df.head(100)
# Out:
#              location              query        date  time temp_C humidity  \
# 0   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13     0     16       81
# 1   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   100     16       84
# 2   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   200     15       86
# 3   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   300     15       87
# 4   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   400     14       88
# 5   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   500     14       89
# 6   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   600     14       90
# 7   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   700     15       89
# 8   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   800     15       86
# 9   Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13   900     16       81
# 10  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1000     17       76
# 11  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1100     19       65
# 12  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1200     21       54
# 13  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1300     22       47
# 14  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1400     22       44
# 15  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1500     22       43
# 16  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1600     21       46
# 17  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1700     20       57
# 18  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1800     19       73
# 19  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  1900     18       74
# 20  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  2000     17       73
# 21  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  2100     17       72
# 22  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  2200     17       71
# 23  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-13  2300     17       70
# 24  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14     0     17       63
# 25  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   100     17       62
# 26  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   200     16       60
# 27  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   300     16       60
# 28  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   400     16       61
# 29  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   500     16       63
# 30  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   600     16       65
# 31  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   700     16       66
# 32  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   800     17       64
# 33  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14   900     18       56
# 34  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1000     20       48
# 35  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1100     21       41
# 36  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1200     22       36
# 37  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1300     23       33
# 38  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1400     23       32
# 39  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1500     23       32
# 40  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1600     23       33
# 41  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1700     21       38
# 42  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1800     20       57
# 43  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  1900     19       67
# 44  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  2000     18       67
# 45  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  2100     17       67
# 46  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  2200     17       67
# 47  Sao Paulo, Brazil  Sao Paulo, Brazil  2025-07-14  2300     16       67
#
#    wind_speed_Kmph          weather_desc precip_mm max_temp_C min_temp_C  \
# 0                8         Partly cloudy       0.0         23         14
# 1                8                 Clear       0.0         23         14
# 2                9                 Clear       0.0         23         14
# 3                9         Partly cloudy       0.0         23         14
# 4                8         Partly cloudy       0.0         23         14
# 5                7         Partly cloudy       0.0         23         14
# 6                8         Partly cloudy       0.0         23         14
# 7                9         Partly cloudy       0.0         23         14
# 8                9         Partly cloudy       0.0         23         14
# 9                9              Overcast       0.0         23         14
# 10              10         Partly cloudy       0.0         23         14
# 11              11         Partly cloudy       0.0         23         14
# 12              10                 Sunny       0.0         23         14
# 13               9                 Sunny       0.0         23         14
# 14               9                 Sunny       0.0         23         14
# 15               9                 Sunny       0.0         23         14
# 16               9         Partly cloudy       0.0         23         14
# 17              15  Patchy rain possible       0.0         23         14
# 18              14         Partly cloudy       0.0         23         14
# 19              12         Partly cloudy       0.0         23         14
# 20              10         Partly cloudy       0.0         23         14
# 21               9         Partly cloudy       0.0         23         14
# 22               9         Partly cloudy       0.0         23         14
# 23               8         Partly cloudy       0.0         23         14
# 24               8         Partly cloudy       0.0         24         15
# 25               8         Partly cloudy       0.0         24         15
# 26               8         Partly cloudy       0.0         24         15
# 27               8                Cloudy       0.0         24         15
# 28               8                Cloudy       0.0         24         15
# 29               8                Cloudy       0.0         24         15
# 30               8                Cloudy       0.0         24         15
# 31               8         Partly cloudy       0.0         24         15
# 32               8         Partly cloudy       0.0         24         15
# 33               8                 Sunny       0.0         24         15
# 34               8                 Sunny       0.0         24         15
# 35               6                 Sunny       0.0         24         15
# 36               6                 Sunny       0.0         24         15
# 37               7                 Sunny       0.0         24         15
# 38               8                 Sunny       0.0         24         15
# 39               9                 Sunny       0.0         24         15
# 40               8                 Sunny       0.0         24         15
# 41               9                 Sunny       0.0         24         15
# 42              13                 Clear       0.0         24         15
# 43              11                 Clear       0.0         24         15
# 44               8                 Clear       0.0         24         15
# 45               6                 Clear       0.0         24         15
# 46               6                 Clear       0.0         24         15
# 47               5                 Clear       0.0         24         15
#
#    avg_temp_C sun_hours uv_index   sunrise    sunset  moonrise   moonset
# 0          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 1          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 2          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 3          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 4          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 5          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 6          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 7          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 8          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 9          17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 10         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 11         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 12         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 13         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 14         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 15         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 16         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 17         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 18         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 19         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 20         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 21         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 22         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 23         17       9.0        5  06:48 AM  05:37 PM  08:25 PM  08:54 AM
# 24         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 25         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 26         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 27         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 28         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 29         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 30         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 31         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 32         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 33         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 34         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 35         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 36         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 37         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 38         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 39         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 40         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 41         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 42         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 43         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 44         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 45         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 46         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM
# 47         18      11.0        5  06:48 AM  05:37 PM  09:24 PM  09:30 AM

# %%
start_date= '2025-06-01'
end_date= '2025-07-05'
# create list of first day of month for range between start and end dates non-inclusive (open)
list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')
# Out:
# C:\Users\johns\AppData\Local\Temp\ipykernel_18340\1370219837.py:4: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_begin = pd.date_range(start_date, end_date, freq='MS', closed='right')

# %%
ist_mon_begin = pd.concat([pd.Series(pd.to_datetime(start_date)), pd.Series(list_mon_begin)], ignore_index=True)

# %%
# create list of month end dates for range between start and end dates non-inclusive (open)
list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')
# Out:
# C:\Users\johns\AppData\Local\Temp\ipykernel_18340\84487024.py:2: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   list_mon_end = pd.date_range(start_date, end_date, freq='M', closed='left')

# %%
list_mon_end = pd.concat([pd.Series(list_mon_end), pd.Series(pd.to_datetime(end_date))], ignore_index=True)

# %%
# count number of months to be retrieved
total_months = len(list_mon_begin)

# %%
total_months
# Out:
# 1

# %%
start_d = str(list_mon_begin[0])[:10]
end_d = str(list_mon_end[0])[:10]

# %%
end_d
# Out:
# '2025-06-30'

# %%
start_d
# Out:
# '2025-07-01'
