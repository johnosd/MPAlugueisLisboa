# %%
import os
import pandas as pd

# %%
base_dir = '..\\..\\Bases\\'
os.chdir(base_dir)
os.getcwd()
# Out:
# 'G:\\Users\\johns\\Desktop\\TCC\\MPAlugueisLisboa\\Bases'

# %%
path_fato = 'Imoveis\\fato\\Base_fato_unificada.csv'
path_detalhe =  'Imoveis\\Detalhes\\BaseDetalhesImovel.csv'
path_municipios = 'Municipios\\df_municipios_ranking_geral.csv'
path_final =  'Imoveis\\BaseFinal.csv'

# %%
df_fato = pd.read_csv(path_fato, sep=';', encoding='utf-8')
df_fato.head(1)
# Out:
#    Unnamed: 0  IdImovel                                        UrlPesquisa  \
# 0           0  30365582  https://www.idealista.pt/arrendar-casas/aveiro...
#
#                  Url                                               Nome  \
# 0  /imovel/30365582/  Apartamento T0 na rua Manuel Lopes Conde, 1, O...
#
#    Preco tipo metros  andar      elevador  \
# 0  400,0   T0   50,0    0.0  sem elevador
#
#                                             Detalhes Status distrito  \
# 0  T0 , 50 m² construídos, Rés do chão  sem elevador     OK   aveiro
#
#    QtdQuartos Preco_Metro
# 0           0         8,0

# %%
df_detalhe = pd.read_csv(path_detalhe, sep=';', encoding='utf-8')
df_detalhe.head(1)
# Out:
#    IdImovel                        Caracteristicas  \
# 0  31627595  104\r\nm² construídos,104,T2,2º andar
#
#                                           Comentario  \
# 0  Proc. º 18195. Livre início Fev/2022 (possibil...
#
#                                             Detalhes  \
# 0  104 m² construídos, 90 m² úteis,T2,2 casas de ...
#
#                                             Endereco   Latitude  Longitude  \
# 0   Matosinhos Sul - Marginal Matosinhos e Leça d...  41.181564  -8.695406
#
#    ad_builtType  ad_characteristics_bathNumber  \
# 0           3.0                            2.0
#
#    ad_characteristics_constructedArea  ...  ad_operation  ad_origin  \
# 0                               104.0  ...           2.0        4.0
#
#    ad_originTypeRecommended  ad_owner_commercialId  ad_owner_commercialName  \
# 0                       NaN                    NaN                habitalia
#
#    ad_owner_contactPreference  ad_owner_type  ad_price  ad_recommendationId  \
# ...

# %%
df_municipio = pd.read_csv(path_municipios, sep=';', encoding='utf-8')
df_municipio.head(1)
# Out:
#    Unnamed: 0 Ambito Geografico Regiao            Cidades  qtd Idade 0 -14  \
# 0           0         Município  Norte  Arcos de Valdevez             1988
#
#    qtd Idade 15-64  qtd idade >65 % Idade 0 -14 % Idade 15-64 % idade >65  \
# 0            12099           6770           9,5          58,0        32,5
#
#    ... % Crimes qtd bancos    Latitude  Longitude  \
# 0  ...     29,2          6  41,8471981  -8,417882
#
#                                          Address  \
# 0  Arcos de Valdevez, Viana do Castelo, Portugal
#
#    distance_driving_Lisboa_Portugal  distance_driving_Porto_Portugal  \
# 0                             353,9                             79,2
#
#    Clima_Ranking  Ranking_Geral  Ranking_Regional
# 0           18,0          127,0              43,0
#
# [1 rows x 34 columns]

# %%
df_fato_detalhes = df_fato.merge(df_detalhe, left_on='IdImovel', right_on='IdImovel', how='inner')

# %%
#transforma em maiusculo todos registros para evitar problemas no merge
df_fato_detalhes['distrito'] = df_fato_detalhes['distrito'].str.upper()
df_municipio['Cidades'] = df_municipio['Cidades'].str.upper()

# %%
df_final = pd.merge(df_fato_detalhes, df_municipio, left_on='distrito', right_on='Cidades', how='left', indicator = True)

# %%
'ad_price', 'ad_recommendationId',
       'ad_typology', 'Ambito Geografico', 'Regiao', 'Cidades',
       'qtd Idade 0 -14', 'qtd Idade 15-64', 'qtd idade >65', '% Idade 0 -14',
       '% Idade 15-64', '% idade >65', 'N.º médio de indivíduos por Km²\t\n\t',
       '% cidadãos estrangeiros,em relacao total da população',
       'qtd Hospitais particulares e publicos', 'qtd Farmacias',
       'Quantidade construçoes novas', 'qtd escolas - pre-escolar -4 -6 anos',
       'qtd escolas - ciclo 1 - 6-10 anos',
       'qtd escolas - ciclo 2 - 10 -12 anos',
       'qtd escolas - ciclo 3 - 13 -15 anos', 'qtd shows,exibicoes,teatro',
       'qtd Cinemas', 'Ganho medio mensal', '% Desempregados',
       '% Poder de compra', '% Crimes', 'qtd bancos', 'Latitude_Municipio',
       'Longitude_Municipio', 'Endereco_Municipio',
       'distance_driving_Lisboa_Portugal', 'distance_driving_Porto_Portugal',
       'Clima_Ranking', 'Ranking_Geral', 'Ranking_Regional'
# Out:
#   Cell In[10], line 2
#     'ad_typology', 'Ambito Geografico', 'Regiao', 'Cidades',
#     ^
# IndentationError: unexpected indent

# %%
import json
dicionario_dados_json =json.loads('''
{
  "ad_builtType": "Tipo_de_Construcao",
  "ad_characteristics_bathNumber": "Numero_de_Banheiros",
  "ad_characteristics_constructedArea": "Area_construida",
  "ad_characteristics_hasGarden": "Possui_Jardim",
  "ad_characteristics_hasLift": "Possui_Elevador",
  "ad_characteristics_hasParking": "Possui_Estacionamento",
  "ad_characteristics_hasSwimmingPool": "Possui_Piscina",
  "ad_characteristics_hasTerrace": "Possui_Terraco",
  "ad_characteristics_roomNumber": "Numero_de_Quartos",
  "ad_isAuction": "Indicador_imovel_esta_em_leilao",
  "ad_isRecommended": "Indicador_Imovel_e_recomendado",
  "ad_numberRecommended": "Numero_de_recomendacoes_recebidas",
  "ad_operation": "Tipo_de_Operacao",
  "andar": "Numero_Andar_do_imovel",
  "Caracteristicas": "Caracteristicas",
  "Comentario": "Comentarios_adicionados",
  "Detalhes": "Detalhes_Imovel",
  "elevador": "Indicador_de_Elevador",
  "IdImovel": "Id_do_imovel",
  "metros": "Valor_Area_util_do_imovel",
  "Nome": "Nome_do_imovel",
  "QtdQuartos": "Quantidade_de_Quartos",
  "tipo": "Tipo_de_Imovel",
  "ad_condition_isGoodCondition": "Indicador_Imovel_em_boas_condicoes",
  "ad_condition_isNeedsRenovating": "Indicador_Precisa_de_reforma",
  "ad_condition_isNewDevelopment": "Indicador_Construcao_recente",
  "ad_energyCertification_suffix": "Nivel_de_eficiencia_Energetica",
  "ad_energyCertification_type": "Tipo_de_Certificacao_Energetica",
  "ad_hasRecommended": "E_Recomendado",
  "distrito": "Distrito_do_imovel",
  "Endereco": "Endereco",
  "Latitude": "Latitude",
  "Longitude": "Longitude",
  "ad_id": "Id_do_anuncio",
  "ad_media_has3Dtour": "Indicador_Anuncio_possui_tour_3d",
  "ad_media_hasFloorPlan": "Indicador_Anuncio_possui_planta_baixa",
  "ad_media_photoNumber": "Numero_de_fotos_do_anuncio",
  "ad_media_videoNumber": "Numero_de_videos_do_anuncio",
  "ad_origin": "Tipo_de_Origem_do_anuncio",
  "ad_originTypeRecommended": "Tipo_de_origem_de_anuncio_recomendada",
  "Status": "Status_do_anuncio",
  "Url": "Url_do_Imovel",
  "UrlPesquisa": "Url_da_Pagina_do_imovel",
  "ad_owner_commercialId": "Id_do_proprietario",
  "ad_owner_commercialName": "Nome_do_proprietario_ou_corretor",
  "ad_owner_contactPreference": "Tipo_de_Preferencia_de_contato_com_o_proprietario",
  "ad_owner_type": "Tipo_de_proprietario",
  "Detalhes_x": "Detalhes",
  "Latitude_x": "Latitude_imovel",
  "Longitude_x": "Longitude_imovel",
  "Latitude_y": "Latitude_Municipio",
  "Longitude_y": "Longitude_Municipio",
  "Address": "Endereco_Municipio",
  "ad_price": "Preco_de_locacao_do_imovel",
  "ad_recommendationId": "ad_recommendationId",
  "ad_typology": "ad_typology",
  "Ambito Geografico": "Ambito_Geografico",
  "Regiao": "Nome_Regiao",
  "Cidades": "Nome_Cidade",
  "qtd Idade 0 -14": "Numero_Faixa_Etaria_0-14",
  "qtd Idade 15-64": "Numero_Faixa_Etaria_15-64",
  "qtd idade >65": "Numero_Faixa_Etaria_>65",
  "% Idade 0 -14": "Percentual_Faixa_Etaria_0-14",
  "% Idade 15-64": "Percentual_Faixa_Etaria_15-64",
  "% idade >65": "Percentual_Faixa_Etaria_>65",
  "N.º médio de indivíduos por Km²\t\n\t": "Densidade_populacional_por_Km",
  "% cidadãos estrangeiros,em relacao total da população": "Densidade_populacional_Estrangeiros",
  "qtd Hospitais particulares e publicos": "Quantidade_Hospitais_(Particulares_e_Publicos)",
  "qtd Farmacias": "Quantidade_Farmacias",
  "Quantidade construçoes novas": "Quantidade_Construcoes_Novas",
  "qtd escolas - pre-escolar -4 -6 anos": "Quantidade_Escolas_Pre-Escolar_(4-6_anos)",
  "qtd escolas - ciclo 1 - 6-10 anos": "Quantidade_Escolas_Ciclo_1_(6-10_anos)",
  "qtd escolas - ciclo 2 - 10 -12 anos": "Quantidade_Escolas_Ciclo_2_(10-12_anos)",
  "qtd escolas - ciclo 3 - 13 -15 anos": "Quantidade_Escolas_Ciclo_3_(13-15_anos)",
  "qtd shows,exibicoes,teatro": "Quantidade_Shows_Exibicoes_Teatro",
  "qtd Cinemas": "Quantidade_Cinemas",
  "Ganho medio mensal": "Renda_Media_Mensal",
  "% Desempregados": "Percentual_Desempregados",
  "% Poder de compra": "Percentual_Poder_de_Compra",
  "% Crimes": "Percentual_Crimes",
  "qtd bancos": "Quantidade_Bancos",
  "Latitude_Municipio": "Latitude_Municipio",
  "Longitude_Municipio": "Longitude_Municipio",
  "Endereco_Municipio": "Endereco_Municipio",
  "distance_driving_Lisboa_Portugal": "Distancia_dirigindo_de_Lisboa_Portugal",
  "distance_driving_Porto_Portugal": "Distancia_dirigindo_de_Porto_Portugal",
  "Clima_Ranking": "Clima_Ranking",
  "Ranking_Geral": "Ranking_Geral",
  "Ranking_Regional": "Ranking_Regional",
  "Preco_Metro":"Preco_por_metro_quadrado"
}
''',strict=False)

# %%
# renomeando as colunas
df_final.rename(columns=dicionario_dados_json, inplace = True)

# %%
# Exclui colunas não usadas
df_final.drop(['Unnamed: 0_x', 'Detalhes_y', 'Unnamed: 0_y','_merge'], axis=1, inplace=True)

# %%
# renomeando as colunas
df_final.columns
# Out:
# Index(['Id_do_imovel', 'Url_da_Pagina_do_imovel', 'Url_do_Imovel',
#        'Nome_do_imovel', 'Preco', 'Tipo_de_Imovel',
#        'Valor_Area_util_do_imovel', 'Numero_Andar_do_imovel',
#        'Indicador_de_Elevador', 'Detalhes', 'Status_do_anuncio',
#        'Distrito_do_imovel', 'Quantidade_de_Quartos',
#        'Preco_por_metro_quadrado', 'Caracteristicas',
#        'Comentarios_adicionados', 'Endereco', 'Latitude_imovel',
#        'Longitude_imovel', 'Tipo_de_Construcao', 'Numero_de_Banheiros',
#        'Area_construida', 'Possui_Jardim', 'Possui_Elevador',
#        'Possui_Estacionamento', 'Possui_Piscina', 'Possui_Terraco',
#        'Numero_de_Quartos', 'Indicador_Imovel_em_boas_condicoes',
#        'Indicador_Precisa_de_reforma', 'Indicador_Construcao_recente',
#        'Nivel_de_eficiencia_Energetica', 'Tipo_de_Certificacao_Energetica',
#        'E_Recomendado', 'Id_do_anuncio', 'Indicador_imovel_esta_em_leilao',
# ...

# %%
# Esporta base final
df_final.to_csv(path_final, sep=';', quotechar='"', decimal=',', encoding='utf-8', index_label="RowId")
