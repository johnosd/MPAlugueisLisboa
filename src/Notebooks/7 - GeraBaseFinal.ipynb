# %%
import os
import pandas as pd

# %%
base_dir = '..\\..\\Bases\\'
os.chdir(base_dir)
os.getcwd()
# Out:
# 'G:\\Users\\johns\\Desktop\\TCC\\MPAlugueisLisboa\\Bases'

# %%
path_fato = 'Imoveis\\fato\\Base_fato_unificada.csv'
path_detalhe =  'Imoveis\\Detalhes\\BaseDetalhesImovel.csv'
path_municipios = 'Municipios\\df_municipios_ranking_geral.csv'
path_final =  'Imoveis\\BaseFinal.csv'

# %%
df_fato = pd.read_csv(path_fato, sep=';', encoding='utf-8')
df_fato.head(1)
# Out:
#    Unnamed: 0  IdImovel                                        UrlPesquisa  \
# 0           0  30365582  https://www.idealista.pt/arrendar-casas/aveiro...
#
#                  Url                                               Nome  \
# 0  /imovel/30365582/  Apartamento T0 na rua Manuel Lopes Conde, 1, O...
#
#    Preco tipo metros  andar      elevador  \
# 0  400,0   T0   50,0    0.0  sem elevador
#
#                                             Detalhes Status distrito  \
# 0  T0 , 50 m² construídos, Rés do chão  sem elevador     OK   aveiro
#
#    QtdQuartos Preco_Metro
# 0           0         8,0

# %%
df_detalhe = pd.read_csv(path_detalhe, sep=';', encoding='utf-8')
df_detalhe.head(1)
# Out:
#    IdImovel                        Caracteristicas  \
# 0  31627595  104\r\nm² construídos,104,T2,2º andar
#
#                                           Comentario  \
# 0  Proc. º 18195. Livre início Fev/2022 (possibil...
#
#                                             Detalhes  \
# 0  104 m² construídos, 90 m² úteis,T2,2 casas de ...
#
#                                             Endereco   Latitude  Longitude  \
# 0   Matosinhos Sul - Marginal Matosinhos e Leça d...  41.181564  -8.695406
#
#    ad_builtType  ad_characteristics_bathNumber  \
# 0           3.0                            2.0
#
#    ad_characteristics_constructedArea  ...  ad_operation  ad_origin  \
# 0                               104.0  ...           2.0        4.0
#
#    ad_originTypeRecommended  ad_owner_commercialId  ad_owner_commercialName  \
# 0                       NaN                    NaN                habitalia
#
#    ad_owner_contactPreference  ad_owner_type  ad_price  ad_recommendationId  \
# 0                         1.0            2.0    1345.0                  NaN
#
#   ad_typology
# 0         1.0
#
# [1 rows x 40 columns]

# %%
df_municipio = pd.read_csv(path_municipios, sep=';', encoding='utf-8')
df_municipio.head(1)
# Out:
#    Unnamed: 0 Ambito Geografico Regiao            Cidades  qtd Idade 0 -14  \
# 0           0         Município  Norte  Arcos de Valdevez             1988
#
#    qtd Idade 15-64  qtd idade >65 % Idade 0 -14 % Idade 15-64 % idade >65  \
# 0            12099           6770           9,5          58,0        32,5
#
#    ... % Crimes qtd bancos    Latitude  Longitude  \
# 0  ...     29,2          6  41,8471981  -8,417882
#
#                                          Address  \
# 0  Arcos de Valdevez, Viana do Castelo, Portugal
#
#    distance_driving_Lisboa_Portugal  distance_driving_Porto_Portugal  \
# 0                             353,9                             79,2
#
#    Clima_Ranking  Ranking_Geral  Ranking_Regional
# 0           18,0          127,0              43,0
#
# [1 rows x 34 columns]

# %%
df_fato_detalhes = df_fato.merge(df_detalhe, left_on='IdImovel', right_on='IdImovel', how='inner')

# %%
#transforma em maiusculo todos registros para evitar problemas no merge
df_fato_detalhes['distrito'] = df_fato_detalhes['distrito'].str.upper()
df_municipio['Cidades'] = df_municipio['Cidades'].str.upper()

# %%
df_final = pd.merge(df_fato_detalhes, df_municipio, left_on='distrito', right_on='Cidades', how='left', indicator = True)

# %%
merged_df.to_csv(path_final, sep=';', quotechar='"', decimal=',')

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0_x', 'IdImovel', 'UrlPesquisa', 'Url', 'Nome', 'Preco',
#        'tipo', 'metros', 'andar', 'elevador', 'Detalhes_x', 'Status',
#        'distrito', 'QtdQuartos', 'Preco_Metro', 'Caracteristicas',
#        'Comentario', 'Detalhes_y', 'Endereco', 'Latitude_x', 'Longitude_x',
#        'ad_builtType', 'ad_characteristics_bathNumber',
#        'ad_characteristics_constructedArea', 'ad_characteristics_hasGarden',
#        'ad_characteristics_hasLift', 'ad_characteristics_hasParking',
#        'ad_characteristics_hasSwimmingPool', 'ad_characteristics_hasTerrace',
#        'ad_characteristics_roomNumber', 'ad_condition_isGoodCondition',
#        'ad_condition_isNeedsRenovating', 'ad_condition_isNewDevelopment',
#        'ad_energyCertification_suffix', 'ad_energyCertification_type',
#        'ad_hasRecommended', 'ad_id', 'ad_isAuction', 'ad_isRecommended',
#        'ad_media_has3Dtour', 'ad_media_hasFloorPlan', 'ad_media_photoNumber',
#        'ad_media_videoNumber', 'ad_numberRecommended', 'ad_operation',
#        'ad_origin', 'ad_originTypeRecommended', 'ad_owner_commercialId',
#        'ad_owner_commercialName', 'ad_owner_contactPreference',
#        'ad_owner_type', 'ad_price', 'ad_recommendationId', 'ad_typology',
#        'Unnamed: 0_y', 'Ambito Geografico', 'Regiao', 'Cidades',
#        'qtd Idade 0 -14', 'qtd Idade 15-64', 'qtd idade >65', '% Idade 0 -14',
#        '% Idade 15-64', '% idade >65', 'N.º médio de indivíduos por Km²\t\n\t',
#        '% cidadãos estrangeiros,em relacao total da população',
#        'qtd Hospitais particulares e publicos', 'qtd Farmacias',
#        'Quantidade construçoes novas', 'qtd escolas - pre-escolar -4 -6 anos',
#        'qtd escolas - ciclo 1 - 6-10 anos',
#        'qtd escolas - ciclo 2 - 10 -12 anos',
#        'qtd escolas - ciclo 3 - 13 -15 anos', 'qtd shows,exibicoes,teatro',
#        'qtd Cinemas', 'Ganho medio mensal', '% Desempregados',
#        '% Poder de compra', '% Crimes', 'qtd bancos', 'Latitude_y',
#        'Longitude_y', 'Address', 'distance_driving_Lisboa_Portugal',
#        'distance_driving_Porto_Portugal', 'Clima_Ranking', 'Ranking_Geral',
#        'Ranking_Regional', '_merge'],
#       dtype='object')

# %%
import json
dicionario_dados_json =json.loads('''
{
    "Endereco": "Endereco",
    "Latitude": "Latitude",
    "Longitude": "Longitude",
    "ad_characteristics_constructedArea": "Área construída",
    "ad_characteristics_hasGarden": "Possui Jardim",
    "ad_characteristics_hasLift": "Possui Elevador",
    "ad_characteristics_hasParking": "Possui Estacionamento",
    "ad_characteristics_hasSwimmingPool": "Possui Piscina",
    "ad_characteristics_hasTerrace": "Possui Terraço",
    "ad_characteristics_roomNumber": "Numero de Quartos",
    "ad_characteristics_bathNumber": "Numero de Banheiros",
    "ad_builtType": "Tipo de Construcao",
    "Caracteristicas": "Caracteristicas",
    "ad_condition_isGoodCondition": "Imovél em boas condições",
    "ad_condition_isNeedsRenovating": "Precisa de reforma",
    "ad_condition_isNewDevelopment": "Construção recente",
    "ad_energyCertification_suffix": "Nivel de eficiencia Energética",
    "ad_energyCertification_type": "Tipo de Certificacao Energética",
    "ad_hasRecommended": "É Recomendado",
    "ad_media_has3Dtour": "Anúncio possui tour 3d",
    "ad_media_hasFloorPlan": "Anúncio possui planta baixa",
    "ad_media_photoNumber": "Numero de fotos do anuncio",
    "ad_media_videoNumber": "Numero de videos do anuncio",
    "ad_price": "Preço do Imóvel",
    "ad_owner_commercialName": "Nome do proprietario ou corretor",
    "ad_owner_contactPreference": "Preferencia de contato com o proprietario",
    "ad_owner_type": "Tipo de proprietario",
    "ad_owner_commercialId": "Id do proprietario",
    "ad_id": "Id do anuncio",
    "ad_isAuction": "Indicador imovel esta em leilão",
    "ad_isRecommended": "Imovel é recomendado",
    "ad_numberRecommended": "Numero de recomendacoes recebidas",
    "ad_operation": "Tipo de Operacao",
    "ad_origin": "Origen do anuncio",
    "ad_originTypeRecommended": "Tipo de origem de anuncio recomendada",
    "Comentario": "Comentarios adicionados",
    "IdImovel": "Id do imovel",
    "UrlPesquisa": "Url da Pagina do imovel",
    "Url": "Url do Imovel",
    "Nome": "Nome do imovel",
    "Preco": "Preço de locação do imovel",
    "tipo": "Tipo de Imovel",
    "metros": "Area util do imovel",
    "andar": "Andar do imovel",
    "elevador": "Indicador de Elevador",
    "Detalhes": "Detalhes Imovel",
    "Status": "Status do anuncio",
    "distrito": "Distrito do imovel",
    "QtdQuartos": "Quantidade de Quartos",
    "Preco_Metro": "Preco por metro quadrado",
    "Ambito Geografico": "ambito_geografico",
    "Regiao": "regiao",
    "Cidades": "cidades",
    "qtd Idade 0 -14": "qtd_idade_0_14",
    "qtd Idade 15-64": "qtd_idade_15_64",
    "qtd idade >65": "qtd_idade_mais_65",
    "% Idade 0 -14": "percent_idade_0_14",
    "% Idade 15-64": "percent_idade_15_64",
    "% idade >65": "percent_idade_mais_65",
    "N.º médio de indivíduos por Km²\t\n\t": "media_individuos_km2",
    "% cidadãos estrangeiros,em relacao total da população": "percent_cidadãos_estrangeiros",
    "qtd Hospitais particulares e publicos": "qtd_hospitais",
    "qtd Farmacias": "qtd_farmacias",
    "Quantidade construçoes novas": "qtd_construcoes_novas",
    "qtd escolas - pre-escolar -4 -6 anos": "qtd_escolas_pre_escolar",
    "qtd escolas - ciclo 1 - 6-10 anos": "qtd_escolas_ciclo1",
    "qtd escolas - ciclo 2 - 10 -12 anos": "qtd_escolas_ciclo2",
    "qtd escolas - ciclo 3 - 13 -15 anos": "qtd_escolas_ciclo3",
    "qtd shows,exibicoes,teatro": "qtd_shows",
    "qtd Cinemas": "qtd_cinemas",
    "Ganho medio mensal": "ganho_medio_mensal",
    "% Desempregados": "percent_desempregados",
    "% Poder de compra": "percent_poder_compra",
    "% Crimes": "percent_crimes",
    "qtd bancos": "qtd_bancos",
    "Latitude": "latitude",
    "Longitude": "longitude",
    "Address": "endereco",
    "distance_driving_Lisboa_Portugal": "distancia_dirigindo_Lisboa_Portugal",
    "distance_driving_Porto_Portugal": "distancia_dirigindo_Porto_Portugal",
    "Clima_Ranking": "ranking_clima",
    "Ranking_Geral": "ranking_geral",
    "Ranking_Regional": "ranking_regional"
     
}
''')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[25], line 2
#       1 import json
# ----> 2 dicionario_dados_json =json.loads('''
#       3 {
#       4     "Endereco": "Endereco",
#       5     "Latitude": "Latitude",
#       6     "Longitude": "Longitude",
#       7     "ad_characteristics_constructedArea": "Área construída",
#       8     "ad_characteristics_hasGarden": "Possui Jardim",
#       9     "ad_characteristics_hasLift": "Possui Elevador",
#      10     "ad_characteristics_hasParking": "Possui Estacionamento",
#      11     "ad_characteristics_hasSwimmingPool": "Possui Piscina",
#      12     "ad_characteristics_hasTerrace": "Possui Terraço",
#      13     "ad_characteristics_roomNumber": "Numero de Quartos",
#      14     "ad_characteristics_bathNumber": "Numero de Banheiros",
#      15     "ad_builtType": "Tipo de Construcao",
#      16     "Caracteristicas": "Caracteristicas",
#      17     "ad_condition_isGoodCondition": "Imovél em boas condições",
#      18     "ad_condition_isNeedsRenovating": "Precisa de reforma",
#      19     "ad_condition_isNewDevelopment": "Construção recente",
#      20     "ad_energyCertification_suffix": "Nivel de eficiencia Energética",
#      21     "ad_energyCertification_type": "Tipo de Certificacao Energética",
#      22     "ad_hasRecommended": "É Recomendado",
#      23     "ad_media_has3Dtour": "Anúncio possui tour 3d",
#      24     "ad_media_hasFloorPlan": "Anúncio possui planta baixa",
#      25     "ad_media_photoNumber": "Numero de fotos do anuncio",
#      26     "ad_media_videoNumber": "Numero de videos do anuncio",
#      27     "ad_price": "Preço do Imóvel",
#      28     "ad_owner_commercialName": "Nome do proprietario ou corretor",
#      29     "ad_owner_contactPreference": "Preferencia de contato com o proprietario",
#      30     "ad_owner_type": "Tipo de proprietario",
#      31     "ad_owner_commercialId": "Id do proprietario",
#      32     "ad_id": "Id do anuncio",
#      33     "ad_isAuction": "Indicador imovel esta em leilão",
#      34     "ad_isRecommended": "Imovel é recomendado",
#      35     "ad_numberRecommended": "Numero de recomendacoes recebidas",
#      36     "ad_operation": "Tipo de Operacao",
#      37     "ad_origin": "Origen do anuncio",
#      38     "ad_originTypeRecommended": "Tipo de origem de anuncio recomendada",
#      39     "Comentario": "Comentarios adicionados",
#      40     "IdImovel": "Id do imovel",
#      41     "UrlPesquisa": "Url da Pagina do imovel",
#      42     "Url": "Url do Imovel",
#      43     "Nome": "Nome do imovel",
#      44     "Preco": "Preço de locação do imovel",
#      45     "tipo": "Tipo de Imovel",
#      46     "metros": "Area util do imovel",
#      47     "andar": "Andar do imovel",
#      48     "elevador": "Indicador de Elevador",
#      49     "Detalhes": "Detalhes Imovel",
#      50     "Status": "Status do anuncio",
#      51     "distrito": "Distrito do imovel",
#      52     "QtdQuartos": "Quantidade de Quartos",
#      53     "Preco_Metro": "Preco por metro quadrado",
#      54     "Ambito Geografico": "ambito_geografico",
#      55     "Regiao": "regiao",
#      56     "Cidades": "cidades",
#      57     "qtd Idade 0 -14": "qtd_idade_0_14",
#      58     "qtd Idade 15-64": "qtd_idade_15_64",
#      59     "qtd idade >65": "qtd_idade_mais_65",
#      60     "% Idade 0 -14": "percent_idade_0_14",
#      61     "% Idade 15-64": "percent_idade_15_64",
#      62     "% idade >65": "percent_idade_mais_65",
#      63     "N.º médio de indivíduos por Km²\t\n\t": "media_individuos_km2",
#      64     "% cidadãos estrangeiros,em relacao total da população": "percent_cidadãos_estrangeiros",
#      65     "qtd Hospitais particulares e publicos": "qtd_hospitais",
#      66     "qtd Farmacias": "qtd_farmacias",
#      67     "Quantidade construçoes novas": "qtd_construcoes_novas",
#      68     "qtd escolas - pre-escolar -4 -6 anos": "qtd_escolas_pre_escolar",
#      69     "qtd escolas - ciclo 1 - 6-10 anos": "qtd_escolas_ciclo1",
#      70     "qtd escolas - ciclo 2 - 10 -12 anos": "qtd_escolas_ciclo2",
#      71     "qtd escolas - ciclo 3 - 13 -15 anos": "qtd_escolas_ciclo3",
#      72     "qtd shows,exibicoes,teatro": "qtd_shows",
#      73     "qtd Cinemas": "qtd_cinemas",
#      74     "Ganho medio mensal": "ganho_medio_mensal",
#      75     "% Desempregados": "percent_desempregados",
#      76     "% Poder de compra": "percent_poder_compra",
#      77     "% Crimes": "percent_crimes",
#      78     "qtd bancos": "qtd_bancos",
#      79     "Latitude": "latitude",
#      80     "Longitude": "longitude",
#      81     "Address": "endereco",
#      82     "distance_driving_Lisboa_Portugal": "distancia_dirigindo_Lisboa_Portugal",
#      83     "distance_driving_Porto_Portugal": "distancia_dirigindo_Porto_Portugal",
#      84     "Clima_Ranking": "ranking_clima",
#      85     "Ranking_Geral": "ranking_geral",
#      86     "Ranking_Regional": "ranking_regional"
#      87
#      88 }
#      89 ''')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Invalid control character at: line 62 column 37 (char 2806)

# %%
# renomeando as colunas
df_final.rename(columns=dicionario_dados_json).columns
